# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.nunique().to_frame
# Out:
# <bound method Series.to_frame of W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64>

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df['W'].nunique()
# Out:
# 24

# %%
df['W'].value_counts().sort_values()
# Out:
# 90     1
# 87     1
# 80     1
# 78     1
# 88     1
# 86     1
# 85     1
# 100    1
# 95     1
# 97     1
# 64     1
# 79     1
# 71     1
# 67     1
# 63     1
# 92     1
# 84     1
# 98     1
# 93     1
# 83     2
# 74     2
# 76     2
# 81     2
# 68     3
# Name: W, dtype: int64

# %% [markdown]
# The no of wins lie from 68 to 100. All have 1 per win expect 83,74,76,81 having 2 wins and 68 having 3 wins

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# 1. There are no missing values
# 2. There are outliers present
# 3. Normal distribution is seen in W,R,AB,2B,3B,SB,ERA,SHO,SV,E mostly
# 4. Right sckewness is present in H,HR,BB,CG  Moslty
# 5. Mean is less than median in SO,RA,ER hence it is negatively or left sckewed

# %% [markdown]
# For Univariate Data:

# %%
for i,col in enumerate(df.columns):
    plt.figure(i)
    sns.countplot(x=col ,data=df)

# %%
sns.catplot(x='W',data=df,kind='count')

# %%
sns.barplot(x='W',y='R',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.barplot(x='W',y='AB',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
sns.barplot(x='W',y='H',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
sns.barplot(x='W',y='2B',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %%
sns.barplot(x='W',y='3B',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %%
sns.barplot(x='W',y='HR',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %%
sns.barplot(x='W',y='HR',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %%
sns.barplot(x='W',y='BB',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='BB'>

# %%
sns.barplot(x='W',y='SO',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %%
sns.barplot(x='W',y='SB',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SB'>

# %%
sns.barplot(x='W',y='RA',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %%
sns.barplot(x='W',y='ER',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %%
sns.barplot(x='W',y='ERA',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %%
sns.barplot(x='W',y='CG',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
sns.barplot(x='W',y='SHO',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
sns.barplot(x='W',y='SV',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
sns.barplot(x='W',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %%
for i,col in enumerate(df.columns):
    plt.figure(i)
    sns.histplot(x=col,data=df)

# %%
for i,col in enumerate(df.columns):
    plt.figure(i)
    sns.scatterplot(x=col ,y='W',data=df)

# %%
for i,col in enumerate(df.columns):
    plt.figure(i)
    sns.regplot(x=col ,y='W',data=df)

# %%
for i,col in enumerate(df.columns):
    plt.figure(i)
    sns.boxplot(y=col,data=df)

# %%
corr=df.corr()

# %%
#to check the correlation and see that alcohol is more correlated and min correlation is with volatile acidity
sns.heatmap(df.corr(),annot=True,annot_kws={'size':7})
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Jaswinder kaur\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
abs(corr['W'].sort_values(ascending=False))
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB     0.087947
# E      0.089485
# SB     0.157234
# 3B     0.251118
# ER     0.809435
# RA     0.812952
# ERA    0.819600
# Name: W, dtype: float64

# %%
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There is a positive relation between SV,BB,SHO,R,2B,HR,SO,CG,H
# and negative relation between AB,E,SB,3B,ER,RA,ERA

# %%
plt.figure(figsize=(20,15))
i=1
for y in df:
    if i<=15:
        ax=plt.subplot(5,3,i)
        sns.distplot(df[y])
        plt.xlabel(y,fontsize=14)
    i+=1
plt.tight_layout()

# %% [markdown]
# 1. Normal distribution is seen in W,R,AB,2B,3B,SB,ERA,SHO,SV,E mostly
# 2. Right sckewness is present in H,HR,BB,CG  Moslty
# 3. Mean is less than median in SO,RA,ER hence it is negatively or left sckewed

# %%
x=df.columns.values
plt.figure(figsize=(15,20))
for i in range(0,len(x)):
    plt.subplot(10,4,i+1)
    sns.boxplot(df[x[i]])
    plt.tight_layout()

# %% [markdown]
# There are not much outliners present but E,SV,SHO,ERA,R have outliers

# %%
X=df.drop(columns=['W'],axis=1)
Y=df['W']
print("Feature Dimension",X.shape)
print("Label Dimension",Y.shape)   #no of rows should be same in features and label
# Out:
# Feature Dimension (30, 16)
# Label Dimension (30,)

# %%
from scipy.stats import zscore
z=np.abs(zscore(X))
z
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29, 17)

# %%
print("Old df: ", df.shape[0])
print("New df",df1.shape[0])
# Out:
# Old df:  30
# New df 29

# %%
Y=Y[(z<3).all(axis=1)]
Y.shape
# Out:
# (29,)

# %%
print("Data Loss Percentage: ", ((df.shape[0]-df1.shape[0])/df.shape[0]*100))
# Out:
# Data Loss Percentage:  3.3333333333333335

# %%
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
X
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# 12 -0.471376 -1.432772 -1.291077 -1.783647 -1.002270  0.395247 -0.607900
# 13 -0.557920  0.400291 -0.436688 -0.715707 -0.904962  1.098383  0.158660
# 14  0.099814  1.208570  0.026106  0.127403  1.430424 -0.563574  0.105179
# 15 -0.713699 -0.465723 -0.312089  0.745685  0.749270 -0.851220  0.657815
# 16  0.151740  1.656011  1.040693  0.970514 -0.418423 -0.755338 -0.144398
# 17  0.013270 -0.364688 -1.113079 -0.153633 -0.126500  0.235444  1.745261
# 18 -0.575229 -0.523457 -0.454487 -0.041219  0.262731 -0.595534 -1.017920
# 19 -0.834861  0.789997 -0.383288 -0.996744 -0.418423  0.107601  0.479546
# 20 -0.090583  0.154920 -0.935081  1.139136 -1.391501  0.427208  0.336930
# 21  0.255593 -1.274002 -0.721484 -0.547085 -1.780732  0.427208  1.246105
# 22 -1.302198 -0.768828  0.293103 -2.177099  0.846578 -1.394552 -1.677518
# 23 -1.994550 -1.389471 -0.757084 -1.333988 -1.294193 -2.033766  0.033871
# 24 -1.077184  0.183787 -0.525687 -0.153633  0.554654 -1.074945 -1.463595
# 25 -0.367523 -1.894646 -1.024080 -0.659500 -0.515731  0.746815  1.673953
# 26  0.134432  0.703396  1.467888  0.745685  0.749270 -0.883181 -0.215706
# 27  0.549843  1.915815  1.610286  0.801892  1.625040 -0.307888  0.372584
# 28 -0.661773 -0.855429 -1.415675 -0.828122  0.457346 -0.499652 -0.768343
# 29  0.844092  0.804431  1.343289 -0.041219  1.722347  0.714854 -1.445768
#
#           SO        SB        RA        ER       ERA        CG       SHO  \
# 0  -2.697630  0.913883 -0.666234 -0.505110 -0.506955 -0.539806 -0.814629
# 1   0.154878 -0.601826  0.165971  0.248930  0.254598 -0.539806  0.172800
# 2  -0.893982  0.111449 -0.680339 -0.751623 -0.641347  2.772641 -0.320914
# 3  -0.168602 -0.690985  0.180076  0.103922  0.053010  1.300442 -0.567771
# 4   0.105866 -0.022290  1.618803  1.597501  1.531318  1.300442  0.172800
# 5  -0.952796  0.200609 -0.257184 -0.389104 -0.350165  1.300442 -0.320914
# 6  -0.207812 -0.913883  0.137760  0.234429  0.165003 -0.171757 -1.802057
# 7   0.811641 -1.760897  0.067235  0.147424  0.209800 -1.275906 -0.320914
# 8   0.605790  0.156029 -0.652129 -0.461608 -0.484557 -0.907856  0.172800
# 9  -0.982204 -0.557246  0.913544  0.843461  0.792164 -0.171757 -0.320914
# 10 -0.148997  0.780144  0.631441  0.640451  0.635374  0.564343 -0.567771
# 11  1.409590  1.671738 -0.990653 -0.925632 -0.865333  0.564343  0.419657
# 12 -0.962599 -1.404260 -0.186658 -0.084588 -0.036584 -0.539806  0.172800
# 13  0.860654 -0.646405  0.532705  0.596948  0.456185  0.932393  0.172800
# 14 -1.266474 -0.245188  0.575021  0.408438  0.411388  0.564343  0.913371
# 15  0.184286 -0.646405 -2.302433 -2.288705 -2.276445 -0.907856  0.913371
# 16  0.723420  0.646405 -1.300966 -1.505663 -1.671683 -1.275906  0.419657
# 17  2.644696  0.512666 -1.131704 -1.302652 -1.335704  0.932393  2.394514
# 18  0.497964  0.022290  0.687862  0.669452  0.724968 -0.907856 -1.061486
# 19  0.066657  2.251273  0.927650  0.930466  0.836961 -0.539806 -0.814629
# 20  0.409742 -1.448839 -1.061179 -1.143144 -1.178913 -0.907856  0.666514
# 21  0.939073 -1.181361 -0.750865 -0.853129 -0.753340  0.196293  0.419657
# 22 -0.962599  1.270521 -0.144343  0.031418  0.142604 -1.275906  0.172800
# 23 -1.384104 -0.646405  1.012281  0.901464  1.016150 -0.171757 -0.320914
# 24  0.252903  0.200609  1.703434  1.641004  1.643311 -0.907856 -1.061486
# 25  0.096064 -1.092202 -1.315071 -1.201147 -1.156515  0.932393  2.394514
# 26 -0.874377  0.423507 -0.863706 -0.563113 -0.529354  1.300442  1.653943
# 27  0.625395  2.162114  0.349338  0.335934  0.187402 -0.907856  0.172800
# 28  0.772432 -0.066870  0.603231  0.277931  0.299395 -0.907856 -1.308343
# 29  0.341125  0.601826  2.197114  2.366042  2.427263  0.196293 -1.802057
#
#           SV         E
# 0   1.671607 -0.461470
# 1   0.249879 -0.607197
# 2  -0.654856 -1.117242
# 3  -0.784104  0.485758
# 4  -1.042600 -0.607197
# 5  -1.171848 -0.461470
# 6   0.637623 -0.097152
# 7  -0.008617 -1.262970
# 8   2.188598  0.048576
# 9  -0.396360  0.194303
# 10  0.249879  1.797303
# 11 -0.525608 -0.680061
# 12  0.379127 -0.097152
# 13  0.249879 -0.024288
# 14 -1.947335  2.307348
# 15  2.447094  0.121439
# 16  1.413111  2.015894
# 17  0.637623  1.214394
# 18 -0.396360  1.578712
# 19 -1.042600 -0.315742
# 20  0.896119 -0.461470
# 21 -0.267112 -0.315742
# 22 -1.042600 -1.262970
# 23  0.120631 -0.315742
# 24 -1.042600  1.651576
# 25  0.508375 -1.408697
# 26 -0.267112 -1.190106
# 27  0.120631 -0.607197
# 28 -0.267112 -0.170015
# 29 -0.913352  0.048576

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#      VIF values Features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297       2B
# 4      3.294146       3B
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %%
X.drop("ER",axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#     VIF values Features
# 0    11.158733        R
# 1     5.863764       AB
# 2     9.628749        H
# 3     3.786446       2B
# 4     3.293109       3B
# 5     9.057309       HR
# 6     3.791451       BB
# 7     2.607389       SO
# 8     1.849280       SB
# 9   122.133235       RA
# 10  119.328698      ERA
# 11    2.741188       CG
# 12    3.410561      SHO
# 13    3.203815       SV
# 14    2.107345        E

# %%
x=df.drop(['W'],axis=1)
y=df['W']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
maxAccu=0
maxRs=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Max r2 score is ",maxAccu,"on Random_state",maxRs)
# Out:
# Max r2 score is  0.9541533838649626 on Random_state 623

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=maxRs,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("r2_score:",r2_score(y_test,pred_LR))
print("r2_score on training data:",r2_score(y_test,pred_LR)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_LR))
print( "mean_squared_error:",mean_squared_error(y_test,pred_LR))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# r2_score: 0.9541533838649626
# r2_score on training data: 95.41533838649626
# Mean absolute error: 2.6505512672728706
# mean_squared_error: 9.317051212331487
# Root mean_squared_error 3.052384512529751

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("r2_score:",r2_score(y_test,pred_RFR))
print("r2_score on training data:",r2_score(y_test,pred_RFR)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_RFR))
print( "mean_squared_error:",mean_squared_error(y_test,pred_RFR))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# r2_score: 0.5830945598687808
# r2_score on training data: 58.30945598687808
# Mean absolute error: 8.185
# mean_squared_error: 84.72444999999999
# Root mean_squared_error 9.204588529641072

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("r2_score:",r2_score(y_test,pred_knn))
print("r2_score on training data:",r2_score(y_test,pred_knn)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_knn))
print( "mean_squared_error:",mean_squared_error(y_test,pred_knn))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2_score: 0.43474029524330227
# r2_score on training data: 43.47402952433023
# Mean absolute error: 9.766666666666667
# mean_squared_error: 114.87333333333335
# Root mean_squared_error 10.717897803829507

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("r2_score:",r2_score(y_test,pred_GBR))
print("r2_score on training data:",r2_score(y_test,pred_GBR)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_GBR))
print( "mean_squared_error:",mean_squared_error(y_test,pred_GBR))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2_score: 0.5014877994835787
# r2_score on training data: 50.14877994835787
# Mean absolute error: 9.065671206848643
# mean_squared_error: 101.30875719383717
# Root mean_squared_error 10.065225143723174

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("r2_score:",r2_score(y_test,pred_lasso))
print("r2_score on training data:",r2_score(y_test,pred_lasso)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_lasso))
print( "mean_squared_error:",mean_squared_error(y_test,pred_lasso))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# r2_score: 0.9784888120778708
# r2_score on training data: 97.84888120778707
# Mean absolute error: 1.556573690835388
# mean_squared_error: 4.371551412174935
# Root mean_squared_error 2.0908255336529002

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("r2_score:",r2_score(y_test,pred_rd))
print("r2_score on training data:",r2_score(y_test,pred_rd)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_rd))
print( "mean_squared_error:",mean_squared_error(y_test,pred_rd))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score: 0.9324142840523124
# r2_score on training data: 93.24142840523125
# Mean absolute error: 3.323831759870965
# mean_squared_error: 13.734919385368967
# Root mean_squared_error 3.706065216016708

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("r2_score:",r2_score(y_test,pred_svr))
print("r2_score on training data:",r2_score(y_test,pred_svr)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_svr))
print( "mean_squared_error:",mean_squared_error(y_test,pred_svr))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score: -0.10489371154792537
# r2_score on training data: -10.489371154792536
# Mean absolute error: 13.984849472819223
# mean_squared_error: 224.53895538012839
# Root mean_squared_error 14.984623965256132

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("r2_score:",r2_score(y_test,pred_etr))
print("r2_score on training data:",r2_score(y_test,pred_etr)*100)
print( "Mean absolute error:",mean_absolute_error(y_test,pred_etr))
print( "mean_squared_error:",mean_squared_error(y_test,pred_etr))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# r2_score: 0.6836034991798796
# r2_score on training data: 68.36034991798796
# Mean absolute error: 6.656666666666666
# mean_squared_error: 64.2988
# Root mean_squared_error 8.018653253508347

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.71136471 -2.21099237  0.38808753  0.73556937  0.5797478 ]
# 0.040755406674662355
# Difference between R2 score and cross_val_score: 91.33979771903003

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [-0.05528144 -5.25131527  0.2677682   0.39437922  0.70260893]
# -0.7883680706650674
# Difference between R2 score and cross_val_score: 137.1462630533848

# %%
score2=cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [-0.52888099 -3.77251908  0.16639756  0.08754788  0.51055621]
# -0.7073796844198347
# Difference between R2 score and cross_val_score: 114.21199796631369

# %%
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [-0.04468537 -6.84485199  0.25765455  0.2922912   0.54541374]
# -1.1588355750615909
# Difference between R2 score and cross_val_score: 166.03233745451695

# %%
score4=cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_lasso)-score4.mean())*100)
# Out:
# [ 0.5598312  -0.89631107  0.54411623  0.5306723   0.88070476]
# 0.323802685612537
# Difference between R2 score and cross_val_score: 65.46861264653337

# %%
score5=cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [ 0.67090465 -2.60020679  0.47831934  0.69410987  0.64922732]
# -0.02152912211965321
# Difference between R2 score and cross_val_score: 95.39434061719656

# %%
score6=cross_val_score(etr,x,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_etr)-score6.mean())*100)
# Out:
# [-0.09722815 -4.21369771  0.38737555  0.36651303  0.74406538]
# -0.562594379212694
# Difference between R2 score and cross_val_score: 124.61978783925736

# %%
score7=cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross_val_score:",(r2_score(y_test,pred_svr)-score7.mean())*100)
# Out:
# [-0.15989899 -0.7621832  -0.31850161 -0.75169003 -0.29872051]
# -0.45819886720715275
# Difference between R2 score and cross_val_score: 35.33051556592274

# %% [markdown]
# as diff btwn r2 score and cross val score is least in SVR. It is the best fitting and performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,0.5,.4,2],'fit_intercept':[True,False],'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs'],'positive':[False,True],'random_state':[1,4,10,20]}
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.5, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.4,
#  'fit_intercept': True,
#  'positive': True,
#  'random_state': 1,
#  'solver': 'auto'}

# %%
Model=Ridge(alpha= 0.4,fit_intercept= True,positive= True, random_state= 1,solver= 'auto')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 Score:",r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print( "mean_squared_error:",mean_squared_error(y_test,pred))
print("Root mean_squared_error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score: 0.9250848778278074
# Mean Absolute Error: 3.4836352512668114
# mean_squared_error: 15.224417605882252
# Root mean_squared_error 3.901847973189403

# %%
import joblib
import pickle
filename='Baseball.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('Baseball.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 92.50848778278073

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                     0          1          2          3          4          5
# Predicted   96.086981  72.006011  68.905861  65.019552  92.288138  82.769229
# Original   100.000000  67.000000  64.000000  63.000000  92.000000  78.000000
